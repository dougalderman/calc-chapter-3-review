# %%
#Problems 51 and 52

# %%
x = var('x')

# %%
def f(x): return (exp(1/x)/(1 + exp(1/x))^2)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -e^(1/x)/(x^2*(e^(1/x) + 1)^2) + 2*e^(2/x)/(x^2*(e^(1/x) + 1)^3)

# %%
p = []

# %%
p.append(plot(f(x),(x,-5,0.001), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,0.001,5), color='blue', legend_label='f(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
table([(x,f(x)) for x in [-2..-0.01, step=.01]])
# Out:
#   -2.00000000000000     0.235003712201594
#   -1.99000000000000     0.234858793267564
#   -1.98000000000000     0.234711794656528
#   -1.97000000000000     0.234562677019471
#   -1.96000000000000     0.234411400088683
#   -1.95000000000000     0.234257922652412
#   -1.94000000000000     0.234102202528715
#   -1.93000000000000     0.233944196538485
#   -1.92000000000000     0.233783860477614
#   -1.91000000000000     0.233621149088274
#   -1.90000000000000     0.233456016029269
#   -1.89000000000000     0.233288413845446
#   -1.88000000000000     0.233118293936109
#   -1.87000000000000     0.232945606522413
#   -1.86000000000000     0.232770300613704
#   -1.85000000000000     0.232592323972757
#   -1.84000000000000     0.232411623079874
#   -1.83000000000000     0.232228143095814
#   -1.82000000000000     0.232041827823490
#   -1.81000000000000     0.231852619668409
#   -1.80000000000000     0.231660459597797
#   -1.79000000000000     0.231465287098364
# ...

# %%
table([(x,f(x)) for x in [0.01..2, step=.01]])
# Out:
#   0.0100000000000000   3.72007597602084e-44
#   0.0200000000000000   1.92874984796392e-22
#   0.0300000000000000   3.33823779536498e-15
#   0.0400000000000000   1.38879438645783e-11
#   0.0500000000000000   2.06115361394185e-9
#   0.0600000000000000   5.77774785177165e-8
#   0.0700000000000000   6.24874170009633e-7
#   0.0800000000000000   3.72662539634621e-6
#   0.0900000000000000   0.0000149448918085087
#   0.100000000000000    0.0000453958077359517
#   0.110000000000000    0.000112660188719705
#   0.120000000000000    0.000240253963099608
#   0.130000000000000    0.000455907722466239
#   0.140000000000000    0.000789242053530546
#   0.150000000000000    0.00126940078074034
#   0.160000000000000    0.00192302235686461
#   0.170000000000000    0.00277273351870260
#   0.180000000000000    0.00383620190572384
#   0.190000000000000    0.00512569571211303
#   0.200000000000000    0.00664805667079016
#   0.210000000000000    0.00840498157642568
# ...

# %%
f(-900000)
# Out:
# e^(-1/900000)/(e^(-1/900000) + 1)^2

# %%
numerical_approx(e^(-1/900000)/(e^(-1/900000) + 1)^2)
# Out:
# 0.249999999999923

# %%
f(900000)
# Out:
# e^(1/900000)/(e^(1/900000) + 1)^2

# %%
numerical_approx(e^(1/900000)/(e^(1/900000) + 1)^2)
# Out:
# 0.249999999999923
